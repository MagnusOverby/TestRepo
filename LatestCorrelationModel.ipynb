# %%
engine='python'
import os
import pytz
from datetime import datetime
import pandas as pd
import pandas.io.data as web
import numpy as np
import subprocess
import matplotlib.pyplot as plt
from zipline.api import order,record,symbol

# %%
#Computation engine
def ComputeCorrelation(InSeries,inCols,percentile,minCorr):
    InSeries1= InSeries.resample('W',how='last')
    inRets = InSeries1.pct_change()
    #inRets = inRets.resample('W',how='mean').fillna(0)
    iMax = len(inRets)
    jMax = len(inRets.columns)
    print iMax
    NrOfDs = 104 #years worth of data
    Carrier = np.zeros([iMax-NrOfDs,jMax,jMax])
    for i in xrange(0,iMax-NrOfDs):
        Carrier[i,:,:]=inRets[i:i+NrOfDs].corr().as_matrix()
    #Build a new Correlation matrix with the Prenentile (variable) Quantile of all our Correlations
    #Percentile is our input parameter which we fudge different 
    adjCorrelation = np.zeros([jMax,jMax])
    for i in range(0,jMax):
        for j in range(0,jMax):
            tmp = np.max([np.percentile(Carrier[:,i,j],percentile)*100,minCorr])
            adjCorrelation[i,j] = tmp
    #Now build a datagrid with these
    Corrs = pd.DataFrame(adjCorrelation,columns=inCols,index=inCols).fillna(minCorr)
    return Corrs

# %%
#Print to a Csv file that resembles simple_input....
#1 start by enumerating all the instruments Sophies Ref and instrument type need [number,ref,type,value]
def WriteToCsv(Corrs,path,nrInput,rets):
  nrInput = len(Corrs)
  Row = []
  Cols = []
  cols = Corrs.columns
  iMax = len(rets)
    
  dvol =  rets[iMax-250:iMax].std()
  yvol = dvol*np.sqrt(250)*100
  Cols.append(['col','ref type','ref','type','vol'])
  for i in range(0,nrInput):
    tmpRow = [i+1,'SOPHISREF',cols[i],'S',np.round(yvol.ix[i],8)]
    Cols.append(tmpRow)
    #add empty row
  Cols.append([])
    #now index and add the correlation matrix with headers 1 to i and indexing 1 to i
    #header
  tmpRow = ['correlation']
  for i in range(0,nrInput):
    tmpRow.append(i+1)
  Cols.append(tmpRow)

  for i in range(0,nrInput):
    tmpRow = [i+1]
    for j in range(0,nrInput):
      tmpRow.append(np.round(Corrs.ix[i,j]/100,8))
    Cols.append(tmpRow)
  
  Cols.append(['Sophis'])
  df = pd.DataFrame(Cols)
  df.to_csv(path,index=False,header=False,sep=';')
  # you cannot shell in IPython
  print "written to file: "+path+ " at : " + str(datetime.now())

# %%
def MakeNwriteCorrelations(data,columns,percentile,minCorr):
    modData = data[columns].T.drop_duplicates().T
    path = 'R:\\apps\sophis_value\GAR_Bulk_VolCorrelUpload\Simple_INPUT.csv'
    Correlations = ComputeCorrelation(modData,modData.columns,percentile,minCorr)
    Returns = modData.pct_change()
    WriteToCsv(Correlations,path,len(Correlations),Returns)

# %%
#Old Section
#MakeNwriteCorrelations(df,usedTickers,80,40)

# %%
def getData(path,start,end):
    head = ['Date','Stock','Price']
    data = pd.read_csv(path,sep='\t+',names=head,parse_dates=['Date']).dropna()
    data.Price = [float(x.replace(',','.')) for x in data.Price]
    return data.pivot(columns='Stock',values='Price',index='Date')[start:end]

# %%
#Loading Stocks
engine = 'python'
path = 'G:\Strukturering\Magnus\Data\stocks20150401.sqy'
start = pd.Timestamp('2008-02-01')
end = pd.Timestamp('2015-03-31')
df = getData(path,start,end)
MakeNwriteCorrelations(df,df.columns,90,25)
# Out:
# 375
# written to file: R:\apps\sophis_value\GAR_Bulk_VolCorrelUpload\Simple_INPUT.csv at : 2015-04-08 10:44:59.710000
# C:\Anaconda\lib\site-packages\pandas\io\parsers.py:615: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators; you can avoid this warning by specifying engine='python'.
#   ParserWarning)

# %%
#Loading Indexes
path = 'G:\Strukturering\Magnus\Data\index20150401.sqy'
start = pd.Timestamp('2008-02-01')
end = pd.Timestamp('2015-03-31')
df = getData(path,start,end)
MakeNwriteCorrelations(df,df.columns,80,20)
# Out:
# 374
# written to file: R:\apps\sophis_value\GAR_Bulk_VolCorrelUpload\Simple_INPUT.csv at : 2015-04-08 10:45:04.422000

# %%
# Creates a Dictionary for Yahoo, good to have in our imp vol search
def findSings(inPut,arrSign,NSign):
    outPut = False
    for x in arrSign: 
        if str(inPut).find(x) > -1:
            outPut = True
            for y in NSign:
                if str(inPut).find(y) > -1:
                    outPut = False
    return outPut
#

tmprr = {}
signs =[".N",".OQ",".O",".P"]
notSigns =[".OL",".PA"]
for x in df.columns:
    if findSings(x,signs,notSigns):
        ids = x.find(".")
        tmprr[x[0:ids]] = x
print tmprr
# Out:
# {'': '.PSI20', 'KFT': 'KFT.N', 'EIDO': 'EIDO.P', 'EWY': 'EWY.P', 'EWS': 'EWS.P', 'EPHE': 'EPHE.P', 'EWT': 'EWT.P'}

# %%
def RunBat():
    BatPath = 'R:\\apps\sophis_value\CORRELATION_local.bat'
    p = subprocess.Popen(BatPath, shell=True, stdout = subprocess.PIPE)

# %%
na = pd.NaT
if na == pd.NaT: 
   na = 0 
print na
# Out:
# NaT

# %%
a = "apagapastapa.N"
a.find(yield x for x in [".OQ",".N"])
# Out:
#   File "<ipython-input-13-4c986c6dbc1b>", line 2
#     a.find(yield x for x in [".OQ",".N"])
#                ^
# SyntaxError: invalid syntax

# %%
a =['ERICb.ST','ELUXb.ST','SEBa.ST','STERV.HE']
JCP = largeCorr[a]
JCP = JCP.T[a]
JCP

# %%
path = 'G:\Strukturering\Magnus\Data\StocksIndex20150408.sqy'
start = pd.Timestamp('2008-02-01')
end = pd.Timestamp('2015-03-31')
df = getData(path,start,end)
MakeNwriteCorrelations(df,df.columns,90,25)
# Out:
# 240
# written to file: R:\apps\sophis_value\GAR_Bulk_VolCorrelUpload\Simple_INPUT.csv at : 2015-04-08 11:59:22.718000

# %%
corr1 = ComputeCorrelation(df,df.columns,80,25)
# Out:
# 240

# %%
stock = ['JCP.N','BBY.N','WHR.N','ANF.N']
corr = ['TLSN.ST']
corr1.columns
# Out:
# Index([u'.AORD', u'.APEEIIER', u'.AXJO', u'.CECEEUR', u'.DBCMHLEU', u'.DBLCMPUE', u'.DJAPSDE', u'.DJDVP', u'.DJI', u'.DJJPSD', u'.FTEPEU', u'.FTSE', u'.FTXIN25', u'.GDAXIP', u'.HFRXGLE', u'.HSCE', u'.HSGMNE', u'.HSI', u'.JTOPI', u'.KS200', u'.KTXUSD', u'.N225', u'.NDX', u'.NSEI', u'.OBX', u'.OBXP', u'.OMXS30', u'.RDXEUR', u'.RDXUSD', u'.RXON', u'.SD3P', u'.SGIXWILS', u'.SIMSCI ', u'.SPGSAGP', u'.SPGSCNP', u'.SPGSENP', u'.SPGSINP', u'.SPGSSBP', u'.SPGSSOP', u'.SPGSWHP', u'.SPTSE', u'.SPX', u'.SSMI', u'.STOXX50E', u'.SX7E', u'.TAMSCI', u'.TOPX', u'.TREIT', u'.TWII', u'.UBCIG10', u'.dMIUC00000PUS', u'/EWZ.P', u'0002.HK', u'0005.HK', u'0006.HK', u'005490.KS', u'005930.KS', u'006400.KS', u'0066.HK', u'010060.KS', u'0144.HK', u'033780.KS', u'066570.KS', u'0700.HK', u'0728.HK', u'0857.HK', u'0883.HK', u'0902.HK', u'0939.HK', u'0941.HK', u'1186.HK', u'1398.HK', u'1800.HK', u'2002.TW', u'2317.TW', u'2319.HK', u'2330.TW', u'2353.TW', u'2357.TW', u'2412.TW', u'2454.TW', u'2777.HK', u'2881.TW', u'2882.TW', u'2885.TW', u'2892.TW', u'3045.TW', u'3481.TW', u'3988.HK', u'4502.T', u'4503.T', u'4568.T', u'6505.TW', u'7269.T', u'908903.FBF', u'AAL.L', u'AAPL.O', u'ABB.ST', u'ABBN.VX', u'ABT.N', ...], dtype='object')

# %%
corr1
# Out:
# Stock               .AORD   .APEEIIER       .AXJO    .CECEEUR  .DBCMHLEU  \
# Stock
# .AORD          100.000000   25.000000   96.236446   54.584681         25
# .APEEIIER       25.000000  100.000000   25.000000   25.000000         25
# .AXJO           96.236446   25.000000  100.000000   58.477121         25
# .CECEEUR        54.584681   25.000000   58.477121  100.000000         25
# .DBCMHLEU       25.000000   25.000000   25.000000   25.000000        100
# .DBLCMPUE       35.479324   25.000000   35.752559   26.559042         25
# .DJAPSDE        71.666140   25.000000   77.452489   56.304511         25
# .DJDVP          74.120575   25.000000   74.050307   58.562072         25
# .DJI            76.700328   25.000000   77.001237   66.119182         25
# .DJJPSD         50.225262   25.000000   49.660828   29.904465         25
# .FTEPEU         69.801363   25.000000   73.122722   68.493206         25
# .FTSE           75.863468   25.000000   78.398748   68.027233         25
# .FTXIN25        64.793735   25.000000   67.556486   62.306492         25
# .GDAXIP         67.990264   25.000000   73.184553   73.061343         25
# .HFRXGLE        66.833803   25.000000   69.963060   54.709288         25
# .HSCE           71.910161   25.000000   71.536970   59.791424         25
# .HSGMNE         53.858253   25.000000   56.277068   53.173942         25
# .HSI            73.784895   25.000000   74.245986   63.904117         25
# .JTOPI          77.591128   25.000000   78.803168   57.123631         25
# .KS200          64.671891   25.000000   66.485649   55.560128         25
# .KTXUSD         70.978163   25.000000   73.158354   69.311130         25
# .N225           62.431763   25.000000   61.772210   41.743968         25
# .NDX            73.298584   25.000000   71.037211   59.353704         25
# .NSEI           56.083302   25.000000   60.320734   58.807551         25
# .OBX            73.615329   25.000000   74.623867   63.884728         25
# .OBXP           75.773417   25.000000   75.436520   62.488475         25
# .OMXS30         74.305150   25.000000   76.833739   70.973959         25
# .RDXEUR         64.997892   25.000000   65.859734   70.935533         25
# .RDXUSD         66.185451   25.000000   66.592852   78.126916         25
# .RXON           25.000000   25.000000   25.000000   25.000000         25
# ...                   ...         ...         ...         ...        ...
# TLSN.ST         46.706593   25.000000   54.746654   50.201539         25
# TMO.N           48.338489   25.000000   57.101135   56.858196         25
# TSCO.L          45.602580   25.000000   45.074468   28.995979         25
# UBCIMEI2=UBCI   25.000000   25.000000   25.000000   25.000000         25
# VTBRq.L         32.725215   25.000000   39.470830   40.453193   25.000000
# VTCOSTE0610     39.876467   25.000000   30.190811   45.649664   38.978270
# VTLANSMA0610    47.580512   25.000000   47.309685   47.067642   51.021852
# VWS.CO          29.967152   25.000000   27.983515   32.840328   25.000000
# WFC             62.108810   42.351257   58.990141   77.491054   58.306849
# WHR             51.685640   31.817750   35.014986   52.339966   49.244854
# WM             100.000000   49.940712   34.057211   69.638529   49.134190
# WMT             49.940712  100.000000   25.000000   44.286004   40.066208
# WRT1V.HE        34.057211   25.000000  100.000000   53.592466   48.437883
# XOM             69.638529   44.286004   53.592466  100.000000   61.429036
# YHOO.OQ         49.134190   40.066208   48.437883   61.429036  100.000000
# YUM.N           39.460059   30.847346   33.540601   52.385210   56.800700
#
# Stock               YUM.N
# Stock
# .AORD           46.874133
# .APEEIIER       25.000000
# .AXJO           43.876363
# .CECEEUR        37.528615
# .DBCMHLEU       25.000000
# .DBLCMPUE       25.000000
# .DJAPSDE        37.871908
# .DJDVP          59.117952
# .DJI            59.972575
# .DJJPSD         25.000000
# .FTEPEU         53.031614
# .FTSE           60.170497
# .FTXIN25        43.135204
# .GDAXIP         52.338832
# .HFRXGLE        54.403911
# .HSCE           33.196921
# .HSGMNE         33.918281
# .HSI            32.834472
# .JTOPI          57.367412
# .KS200          29.838940
# .KTXUSD         53.979009
# .N225           25.000000
# .NDX            64.287144
# .NSEI           26.166615
# .OBX            59.018175
# .OBXP           59.916319
# .OMXS30         54.984865
# .RDXEUR         37.908957
# .RDXUSD         42.372116
# .RXON           25.000000
# ...                   ...
# TLSN.ST         39.663888
# TMO.N           46.818334
# TSCO.L          25.000000
# UBCIMEI2=UBCI   25.000000
# UBCIV24=UBCI    25.000000
# UBCIYCOM=UBSL   39.377863
# UBSN.VX         50.027630
# UELSA100        25.000000
# ULVR.L          25.000000
# UPM1V.HE        55.937898
# URKAq.L         25.000000
# VALE.N          44.171918
# VOD.L           25.000000
# VOLVa.ST        58.533985
# VOLVb.ST        57.986027
# VOWG.DE         50.105714
# VOWG_p.DE       55.268795
# VTBALK0610      35.949308
# VTBRq.L         25.305499
# VTCOSTE0610     35.842785
# VTLANSMA0610    45.727117
# VWS.CO          25.000000
# WFC             52.341990
# WHR             48.215152
# WM              39.460059
# WMT             30.847346
# WRT1V.HE        33.540601
# XOM             52.385210
# YHOO.OQ         56.800700
# YUM.N          100.000000
#
# [291 rows x 291 columns]

# %%
#Finding minimum Correlation Matrix
#Defining start Correlation Matrix
CorrL = Corrs
iMax = len(StartCorr.columns)
#Producing a greedy algo that starts joining the smallest pairs together until we have a 4 cycle. <- not a viable methodology
# m
#Do a brute force search....
Nmn = []
Nmn_Best = []
NBest = 99999
size = 3
tmpMtrx = np.zero([size,size])

# picks next number compares to the list in compTo (to determine the total distance)
def Picknext(CMtrx,compTo):
    tmpDist= 0
    bstDist = 99999
    bstInd = 0
    for y in CMtrx: 
        if not(y in compTo):
            tmpDist = np.sum([y-x for x in compTo])
            if tmpDist < bstDist:
                bstInd = y
    return y
for i in range(0,iMax):
    Nmn.append (CorrL.columns[i])
    for j in range(i,iMax):
        oldNmn = Nmn.copy()
        Nmn.append (Picknext(CorrL,oldNmn))
